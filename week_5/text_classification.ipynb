# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.ml.feature import RegexTokenizer, CountVectorizer, StringIndexer
from pyspark.ml.classification import LogisticRegression, MultilayerPerceptronClassifier
from pyspark.ml.pipeline import Pipeline
from pyspark.ml.evaluation import MulticlassClassificationEvaluator, BinaryClassificationEvaluator
import pandas as pd
from pyspark.ml.tuning import TrainValidationSplit
import findspark
findspark.init()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pyspark
#       2 from pyspark.sql import SparkSession
# ----> 3 from pyspark.ml.feature import RegexTokenizer, CountVectorizer, StringIndexer
#       4 from pyspark.ml.classification import LogisticRegression, MultilayerPerceptronClassifier
#       5 from pyspark.ml.pipeline import Pipeline
#
# File e:\giao_trinh\4.1_ky1_4\nlp\code\.venv\Lib\site-packages\pyspark\ml\__init__.py:31
#      22 from pyspark.ml.base import (
#      23     Estimator,
#      24     Model,
#    (...)     28     UnaryTransformer,
#      29 )
#      30 from pyspark.ml.pipeline import Pipeline, PipelineModel
# ---> 31 from pyspark.ml import (
#      32     classification,
#      33     clustering,
#      34     evaluation,
#      35     feature,
#      36     fpm,
#      37     image,
#      38     recommendation,
#      39     regression,
#      40     stat,
#      41     tuning,
#      42     util,
#      43     linalg,
#      44     param,
#      45 )
#      46 from pyspark.ml.torch.distributor import TorchDistributor
#      48 __all__ = [
#      49     "Transformer",
#      50     "UnaryTransformer",
#    (...)     70     "TorchDistributor",
#      71 ]
#
# File e:\giao_trinh\4.1_ky1_4\nlp\code\.venv\Lib\site-packages\pyspark\ml\image.py:31
#      28 from typing import Any, Dict, List, NoReturn, Optional, cast
#      30 import numpy as np
# ---> 31 from distutils.version import LooseVersion
#      33 from pyspark import SparkContext
#      34 from pyspark.sql.types import Row, StructType, _create_row, _parse_datatype_json_string
#
# ModuleNotFoundError: No module named 'distutils'

# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("text_classification").getOrCreate()

# %%
df = spark.read.option("header", "true").csv(r"E:\giao_trinh\4.1_ky1_4\nlp\code\data\sentiments.csv")
df.show()
# Out:
# +--------------------+---------+
# |                text|sentiment|
# +--------------------+---------+
# |Kickers on my wat...|        1|
# |user: AAP MOVIE. ...|        1|
# |user I'd be afrai...|        1|
# |   MNTA Over 12.00  |        1|
# |    OI  Over 21.37  |        1|
# |   PGNX  Over 3.04  |        1|
# |AAP - user if so ...|       -1|
# |Monday's relative...|       -1|
# |GOOG - ower trend...|        1|
# |AAP will watch to...|        1|
# |i'm assuming FCX ...|        1|
# |It really worries...|        1|
# |AAP GAMCO's arry ...|        1|
# |user Maykiljil po...|        1|
# |Momentum is comin...|        1|
# |HA Hitting 35.65 ...|        1|
# |user gameplan sho...|        1|
# |with FCX gapping ...|        1|
# |user great list a...|        1|
# |ATHX upper trend ...|        1|
# +--------------------+---------+
# only showing top 20 rows

# %%
df = df.na.drop()

# %%
index = StringIndexer(inputCol="sentiment", outputCol="label")
tokenizer = RegexTokenizer(inputCol="text", outputCol="words")
vectorizer = CountVectorizer(inputCol="words", outputCol="features")

pipeline = Pipeline(stages=[index, tokenizer, vectorizer])
model = pipeline.fit(df)

df = model.transform(df)
df.show()

# %% [markdown]
# # Classification with logistic regression
