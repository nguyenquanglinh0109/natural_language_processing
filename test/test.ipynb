# %%
b = set()
a = [1,2,3,4,5,1]
b.update(a)
b
# Out:
# {1, 2, 3, 4, 5}

# %%
a = {}
if a:
    print('and')
else:
    print('None a')
# Out:
# None a

# %%
a = set()
b = ["xin", "chào", "bạn"]
c = ["chào", "thế", "giới"]
a.update(b)
print(a)
a.update(c)
print(a)
# Out:
# {'chào', 'xin', 'bạn'}
# {'chào', 'bạn', 'thế', 'xin', 'giới'}

# %%
import re
pattern = r"\w+|[^\w\s]"
tokens = re.findall(pattern, "insert's somthing,  like! you")
print(tokens)
# Out:
# ['insert', "'", 's', 'somthing', ',', 'like', '!', 'you']
